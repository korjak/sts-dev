# %%
import pandas as pd
import csv

# %%
cos = pd.read_csv(r'C:\Users\a.szlendak\Desktop\daneinz\repo\sts-dev\bert-large-nli-stsb-mean-tokens_results.csv' , error_bad_lines=False, engine='python')
c=cos['1.0000'][cos['1.0000'].notna()]
c
# Out:
# 0        1.0000
# 1        1.0000
# 2        1.0000
# 3        1.0000
# 4        1.0000
#           ...
# 49994   -0.2433
# 49995   -0.2435
# 49996   -0.2449
# 49997   -0.2545
# 49998   -0.2636
# Name: 1.0000, Length: 49999, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.RandomState(10)  # deterministic random data
a = np.hstack((rng.normal(size=1000),
               rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(c, bins='auto')  # arguments are passed to np.histogram
plt.title("cosine similarity on 50k pairs")
plt.show()
